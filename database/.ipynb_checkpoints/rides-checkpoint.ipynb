# %%
import mysql.connector
import pandas as pd
import hashlib
from datetime import datetime

# Get current date and time
now = datetime.now()

# Separate them
today_date = now.date()   # Gives just the date (YYYY-MM-DD)
current_time = now.time() 
# Connect
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="40418",
    database="aeras"
)
print("✅ Connected!")

# Buffered cursor avoids unread result issues
cursor = conn.cursor(buffered=True)

# Functions
def encoding(input_string):
    return hashlib.sha256(input_string.encode('utf-8')).hexdigest()

def genID(userid, pullerid, current_time, today_date):
    return encoding(pullerid + userid + current_time + today_date)


# Get next ID
cursor.execute("SELECT COUNT(*) FROM rides")
iD = cursor.fetchone()[0] + 1
# Out:
# ✅ Connected!

# %%
cursor.execute("TRUNCATE TABLE rides")
conn.commit()
df = pd.read_sql("SELECT * FROM rides", conn)
print(df)

# %%
cursor.execute("ALTER TABLE rides ADD pickup_time varchar(256) ;")
cursor.execute("ALTER TABLE rides ADD drop_time varchar(256) ;")
cursor.execute("ALTER TABLE rides ADD completion_time varchar(256) ;")
conn.commit()

# %%
df = pd.read_sql("SELECT * FROM rides", conn)
print(df)

# %% [markdown]
# cursor.execute("alter table rides modify column status varchar(256) primary key;")
# conn.commit()

# %%
start="Pahartoli"
dest="Raozan"
status="successful"
abs_status=1

# %%
# Generate ride ID
rideid = genID(userid, pullerid, str(current_time), str(today_date))

# Prepare other fields
data = (
    rideid,
    str(today_date),
    str(current_time),
    encoding(userid),
    encoding(pullerid),
    start,
    dest,
    status,
    abs_status
)

# Execute insert
cursor.execute(insert_query, data)
conn.commit()
